# %% [markdown]
# <a href="https://colab.research.google.com/github/vivek97vivu/vivek/blob/master/Seaborn_vj.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
df=sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#corelation
df.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
#heatmap
sns.heatmap(df.corr())

# %%
#jointpolt
sns.jointplot(x='tip',y='total_bill',data=df,kind='reg')

# %%
sns.jointplot(x='tip',y='size',data=df,kind='reg')

# %%
sns.jointplot(x='tip',y='total_bill',data=df,kind='hex')

# %%
#pairplot
sns.pairplot(df)

# %%
df['day'].value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
df['time'].value_counts()
# Out:
# Dinner    176
# Lunch      68
# Name: time, dtype: int64

# %%
df['sex'].value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
df['smoker'].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
# pairplot
sns.pairplot(df,hue='time')

# %%
sns.pairplot(df,hue='sex')

# %%
#
sns.countplot('sex',data=df)
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot('time',data=df)

# %%
sns.countplot('day',data=df)

# %%
sns.countplot('sex',data=df,hue='smoker')

# %%
sns.countplot('sex',data=df,hue='time')

# %%
sns.countplot('day',data=df,hue='smoker')

# %%
sns.barplot(x='total_bill',y='sex',data=df)

# %%
sns.barplot(x='total_bill',y='day',data=df)

# %%
sns.boxplot(x='smoker',y='total_bill',data=df)

# %%
#boxplot
sns.boxplot(x='smoker',y='total_bill',data=df,hue='day')

# %%
#
